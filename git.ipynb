# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/tensorflow_certificate
# Out:
# /content/drive/MyDrive/Colab Notebooks/tensorflow_certificate

# %%
# !pwd && ls -al
# Out:
# /content/drive/MyDrive/Colab Notebooks/tensorflow_certificate
# total 6
# -rw------- 1 root root 1721 Sep 17 13:23 git.ipynb
# drwx------ 2 root root 4096 Sep 17 11:20 sequences_time_series_and_prediction

# %%
#!git init
# !git config --global user.email "fromptj@gmail.com"
# !git config --global user.name "fromptj"

# %%
# !git remote remove origin

# %%
# !git remote add origin https://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@github.com/fromptj/tensorflow_certificate.git

# %%
# !git add .
# !git commit -m "3rd courses 2,3 assignment commit"
# !git push origin master
# Out:
# [master f0e099b] 3rd courses assignment commit
#  1 file changed, 1 insertion(+), 1 deletion(-)
# Counting objects: 22, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (22/22), done.
# Writing objects: 100% (22/22), 141.92 KiB | 5.26 MiB/s, done.
# Total 22 (delta 6), reused 0 (delta 0)
# remote: Resolving deltas: 100% (6/6), completed with 1 local object.
# To https://github.com/fromptj/tensorflow_certificate.git
#    2b818c9..f0e099b  master -> master
