# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/tensorflow_certificate
# Out:
# /content/drive/MyDrive/Colab Notebooks/tensorflow_certificate

# %%
# !pwd && ls -al
# Out:
# /content/drive/My Drive/Colab Notebooks/tensorflow_certificate
# total 16
# drwx------ 7 root root 4096 Sep 20 13:57 .git
# -rw------- 1 root root 3933 Sep 20 13:57 git.ipynb
# drwx------ 2 root root 4096 Sep 18 10:46 natural_language_processing_in_tensorflow
# drwx------ 2 root root 4096 Sep 17 11:20 sequences_time_series_and_prediction

# %%
#!git init
# !git config --global user.email "fromptj@gmail.com"
# !git config --global user.name "fromptj"

# %%
# !git remote remove origin

# %%
# !git remote add origin https://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@github.com/fromptj/tensorflow_certificate.git

# %%
# !git add .
# !git commit -m "sarcasm modeling"
# !git push origin master
# Out:
# [master edd82fb] sarcasm modeling
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite git.ipynb (77%)
# Counting objects: 16, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (16/16), done.
# Writing objects: 100% (16/16), 194.55 KiB | 3.14 MiB/s, done.
# Total 16 (delta 7), reused 0 (delta 0)
# remote: Resolving deltas: 100% (7/7), completed with 3 local objects.
# To https://github.com/fromptj/tensorflow_certificate.git
#    f4f6add..edd82fb  master -> master
