# %%
from google.colab import drive
drive.mount('/content/drive/')

# %%
# %cd drive/MyDrive/Colab Notebooks/tensorflow_certificate
# Out:
# /content/drive/MyDrive/Colab Notebooks/tensorflow_certificate

# %%
# !pwd && ls -al
# Out:
# /content/drive/MyDrive/Colab Notebooks/tensorflow_certificate
# total 6
# -rw------- 1 root root 1721 Sep 17 13:23 git.ipynb
# drwx------ 2 root root 4096 Sep 17 11:20 sequences_time_series_and_prediction

# %%
#!git init
# !git config --global user.email "fromptj@gmail.com"
# !git config --global user.name "fromptj"
# Out:
# Initialized empty Git repository in /content/drive/My Drive/Colab Notebooks/tensorflow_certificate/.git/

# %%
# !git remote add origin https://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@github.com/fromptj/tensorflow_certificate.git

# %%
# !git add .
# !git commit -m "3rd courses assignment commit"
# !git push origin master
# Out:
# [master (root-commit) 2b818c9] 4th courses assignment commit
#  2 files changed, 2 insertions(+)
#  create mode 100644 git.ipynb
#  create mode 100644 sequences_time_series_and_prediction/C4_W4_Assignment.ipynb
# Counting objects: 5, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 113.56 KiB | 7.10 MiB/s, done.
# Total 5 (delta 0), reused 0 (delta 0)
# remote:
# remote: Create a pull request for 'master' on GitHub by visiting:
# remote:      https://github.com/fromptj/tensorflow_certificate/pull/new/master
# remote:
# To https://github.com/fromptj/tensorflow_certificate.git
#  * [new branch]      master -> master

# %%
# !git branch -d main
# !git push origin main
# Out:
# error: branch 'main' not found.
# error: src refspec main does not match any.
# error: failed to push some refs to 'https://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@github.com/fromptj/tensorflow_certificate.git'
